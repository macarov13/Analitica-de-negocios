# %% [markdown]
# <a href="https://colab.research.google.com/github/macarov13/Analitica-de-negocios/blob/main/Reto1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Reto 1**
# Maria Antonia Caro V.
#
# 0. Se procede con la carga de las librerias de trabajo

# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %% [markdown]
# 1. Se cargan los datos

# %%
nxl='/content/sample_data/1. BD1_Longitudinal Survey_Int.xlsx'
XDB=pd.read_excel(nxl,sheet_name=0)
XDB=XDB.dropna()
print(XDB)
#Seleccionar variables de interes
XDB=XDB[['Age','Mother_Edu','Father_Edu','Height','Weight','Income','Self_Esteem','FamilySize']]
#Datos de entrada - np.array - convertir a numeros
XD=np.array(XDB[['Age','Mother_Edu','Father_Edu','Height','Weight','Income','Self_Esteem','FamilySize']])

#Datos de salida
yd=np.array(XDB['FamilySize'])

num_decimales=5
print(np.round(u, num_decimales))
print(np.round(sigma, num_decimales))
# Out:
#        Age  Mother_Edu  Father_Edu  FamilySize  Self_Esteem  Height  Weight  \
# 0       21         8.0         8.0         1.0          0.0     0.0     1.0
# 1       20         5.0         8.0         8.0          0.0     0.0     1.0
# 2       18        10.0        12.0         3.0          0.0     0.0     1.0
# 3       17        11.0        12.0         3.0          0.0     0.0     1.0
# 4       20        12.0        12.0         1.0          0.0     0.0     1.0
# ...    ...         ...         ...         ...          ...     ...     ...
# 12678   21         0.0         8.0         8.0         10.0     1.0     0.0
# 12679   20         0.0        12.0        12.0          3.0     0.0     0.0
# 12681   20         0.0        12.0        12.0          8.0     0.0     0.0
# 12682   20         1.0        12.0        14.0         14.0     0.0     0.0
# 12683   19         1.0         9.0         8.0          3.0     0.0     0.0
#
#        Income
# 0         1.0
# 1         1.0
# ...

# %% [markdown]
# 2. Implementamos Modelo

# %%
mnb=GaussianNB()
mnb.fit(XD,yd)
ydp=mnb.predict(XD)

#Parametro de las medias de las variables para cada categoria
u=mnb.theta_ #Se estiman las medidas
sigma=np.sqrt(mnb.var_) #Se estiman las varianzas

#Las variaciones de las variables
LI=u-sigma
LS=u+sigma
print("La medida de las variables por categoria:")
print(u)
print("El limite inferior de la variacion de las variables por categoria es:")
print(LI)
print("El limite superior de la variacion de las variables por categora es:")
print(LS)
print("La varianza de las variables por categoria es:")
print(sigma)

#Metrica de evaluación
cm=confusion_matrix(yd,ydp)

XD = XDB.drop('FamilySize', axis=1)
yd = XDB['FamilySize']

num_decimales=5
print(np.round(u, num_decimales))
print(np.round(sigma, num_decimales))
# Out:
# La medida de las variables por categoria:
# [[1.87421053e+01 1.05789474e+00 4.46842105e+00 1.21052632e-01
#   7.00000000e-01 1.15789474e-01 6.01052632e+00 0.00000000e+00]
#  [1.87096774e+01 6.63440860e+00 9.03225806e+00 1.07526882e-01
#   6.88172043e-01 5.05376344e-01 3.26881720e+00 1.00000000e+00]
#  [1.84712644e+01 5.70689655e+00 8.71839080e+00 1.14942529e-01
#   7.12643678e-01 4.13793103e-01 3.83908046e+00 2.00000000e+00]
#  [1.84257028e+01 2.92369478e+00 7.41365462e+00 2.48995984e-01
#   5.54216867e-01 3.09236948e-01 5.10441767e+00 3.00000000e+00]
#  [1.83502304e+01 2.04147465e+00 8.03686636e+00 3.08755760e-01
#   4.37788018e-01 2.53456221e-01 5.05069124e+00 4.00000000e+00]
#  [1.84000000e+01 1.09729730e+00 7.77297297e+00 2.97297297e-01
#   3.45945946e-01 2.48648649e-01 5.06486486e+00 5.00000000e+00]
#  [1.89741379e+01 8.49137931e-01 8.51939655e+00 2.41379310e-01
#   3.42672414e-01 2.71551724e-01 4.88793103e+00 6.00000000e+00]
# ...

# %% [markdown]
# 3. Se procede con la evaluacion del modelo

# %%
VN=cm[0,0] #Verdadero Negativo
FP=cm[0,1] #Falso Positivo
FN=cm[1,0] #Falso Negativo
VP=cm[1,1] #Verdadero Positivo

Exactitud=(VP+VN)/len(XD)
print("La exactitud del modelo es:", Exactitud) #Comportamiento general

Tasa_de_error=(FN+FP)/len(XD)
print("La tasa de error es:", Tasa_de_error) #Porcentaje de equivocación
Sensibilidad=VP/(VP+FN)
print("La sensibilidad es:", Sensibilidad) #Como se comporto frente a los positivos

Especificidad=VN/(VN+FN)
print("La especificidad es:", Especificidad) #Como se comporto frente a los negativos

Precisión=VP/(VP+FN)
print("La precisión es", Precisión) #Como le pego a los positivos

PredNeg=VN/(VN+FP)
print("La probabilidad de negativo es", PredNeg) #Como le pego a los negativos
# Out:
# La exactitud del modelo es: 0.027321876810195017
# La tasa de error es: 0.0
# La sensibilidad es: 1.0
# La especificidad es: 1.0
# La precisión es 1.0
# La probabilidad de negativo es 1.0

# %% [markdown]
# 4. ¿Para una persona con las siguientes características indicar si vive en la ciudad o las áreas rurales ['Age','Mother_Edu','Father_Edu','Height','Weight','Income','Self_Esteem','FamilySize']=[34,9,6,65,135,50000,30,3]?

# %%
Xun=np.array([[34,9,6,65,135,50000,30,3]])
ydun=mnb.predict(Xun)
print(ydun)
# Out:
# [1.]

# %% [markdown]
# 5. Análisis de Resultados:
#
# ¿Cuál es el número de datos total de la base de datos? El número total de datos en la base de datos es de 10358.
#
# ¿Cuál es el porcentaje de los datos que hacen parte de cada una de las categorías de clasificación?
#
# Determinar el intervalo en el cual se encuentra la variación de la Edad
#
# Determinar el intervalo en el cual se encuentra la variación de la Altura
#
# Determinar el intervalo en el cual se encuentra la variación del Peso de las Personas
#
# ¿Cuál es la exactitud alcanzada por el modelo?
#
# ¿Cuál es la tasa de error alcanzada por el modelo?
#
# ¿Cuál es la Sensibilidad alcanzada por el modelo?
#
# ¿Cuál es la Especificidad alcanzada por el modelo?
